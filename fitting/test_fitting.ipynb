# %%
ls input
# Out:
# __pycache__/
# param_fit_UMtunedcontinuity_12logbins.py
# param_fit_continuity_12logbins.py
# param_fit_continuity_12logbins_zsortafit.py
# param_fit_dirichlet_12logbins.py
# param_fit_dirichlet_12logbins_zsortafit.py
# param_fit_dirichlet_20logbins.py
# param_fit_dirichlet_8logbins_older1Gyr.py
# param_fit_dirichlet_8logbins_older1Gyr_zsortafit.py
# param_fit_setup.py
# param_fit_setup_zsortafit.py
# run_prospect_postprocessing.py

# %% [raw]
# fit_DF44_aD1_phot_1649889938_mcmc

# %%
# %run input/param_fit_dirichlet_12logbins.py --alphaD 1 --fit_phot 1 --fit_spectra 0 --fit_redshift 0 --outfile output/fit_DF44_aD1_phot --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_phot
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 0
#     fit_phot: 1
#     fit_sigma: False
#     fit_redshift: 0
#     fit_mass: True
#     wave_range: [0, 10000]
#     max_snr: 1000000
#     npoly: 3
# ...

# %% [raw]
# fit_DF44_aD1_phot_specKCWI_zsortafit_npoly8_1649733960_mcmc

# %%
# %run input/param_fit_dirichlet_12logbins_zsortafit.py --alphaD 1 --fit_phot 1 --fit_spectra 1 --npoly 8 --outfile output/fit_DF44_aD1_phot_specKCWI_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_phot_specKCWI_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 1
#     fit_sigma: False
#     fit_mass: True
#     wave_range: [0, 10000]
#     max_snr: 1000000
#     npoly: 8
#
# ...

# %% [raw]
# fit_DF44_aD1_phot_specKCWI_zfixed_npoly3_1649733960_mcmc

# %%
# %run input/param_fit_dirichlet_12logbins.py --alphaD 1 --fit_phot 1 --fit_spectra 1 --fit_redshift 0 --npoly 3 --outfile output/fit_DF44_aD1_phot_specKCWI_zfixed_npoly3 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_phot_specKCWI_zfixed_npoly3
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 1
#     fit_sigma: False
#     fit_redshift: 0
#     fit_mass: True
#     wave_range: [0, 10000]
# ...

# %% [raw]
# fit_DF44_aD1_specKCWI_massfixed_zsortafit_npoly8_1634082827_mcmc

# %%
# %run input/param_fit_dirichlet_12logbins_zsortafit.py --alphaD 1 --fit_phot 0 --fit_spectra 1 --fit_mass 0 --npoly 8 --outfile output/fit_DF44_aD1_specKCWI_massfixed_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_specKCWI_massfixed_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 0
#     fit_sigma: False
#     fit_mass: 0
#     wave_range: [0, 10000]
#     max_snr: 1000000
#     npoly: 8
# ...

# %% [raw]
# fit_DF44_aD1_specKCWI_zsortafit_npoly8_1634071305_mcmc

# %%
# %run input/param_fit_dirichlet_12logbins_zsortafit.py --alphaD 1 --fit_phot 0 --fit_spectra 1 --fit_mass 1 --npoly 8 --outfile output/fit_DF44_aD1_specKCWI_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_specKCWI_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 0
#     fit_sigma: False
#     fit_mass: 1
#     wave_range: [0, 10000]
#     max_snr: 1000000
#     npoly: 8
#
#
# ...

# %% [raw]
# fit_DF44_aD1_older1Gyr_phot_specKCWI_zsortafit_npoly8_1649879742_mcmc

# %%
# %run input/param_fit_dirichlet_8logbins_older1Gyr_zsortafit.py --alphaD 1 --fit_phot 1 --fit_spectra 1 --npoly 8 --outfile output/fit_DF44_aD1_older1Gyr_phot_specKCWI_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_older1Gyr_phot_specKCWI_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 1
#     fit_sigma: False
#     fit_mass: True
#     wave_range: [0, 10000]
#     max_snr: 1000000
# ...

# %%
fit_DF44_aD1_older1Gyr_phot_specKCWI_zfixed_npoly3_1687841282_mcmc

# %%
# %run input/param_fit_dirichlet_8logbins_older1Gyr.py --alphaD 1 --fit_phot 1 --fit_spectra 1 --npoly 3 --outfile output/fit_DF44_aD1_older1Gyr_phot_specKCWI_zfixed_npoly3 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_older1Gyr_phot_specKCWI_zfixed_npoly3
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 1
#     fit_sigma: False
#     fit_redshift: True
#     fit_mass: True
#     wave_range: [0, 10000]
# ...

# %% [raw]
# fit_DF44_aD1_phot_specKCWI_zsortafit_npoly8_maxsnr5_1649879779_mcmc

# %%
# %run input/param_fit_dirichlet_12logbins_zsortafit.py --alphaD 1 --fit_phot 1 --fit_spectra 1 --fit_mass 1 --npoly 8 --max_snr 5 --outfile output/fit_DF44_aD1_specKCWI_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_specKCWI_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     alphaD: 1.0
#     fit_spectra: 1
#     fit_phot: 0
#     fit_sigma: False
#     fit_mass: 1
#     wave_range: [0, 10000]
#     max_snr: 5.0
#     npoly: 8
#
#
# ...

# %% [markdown]
# fit_DF44_csfrcont_phot_specKCWI_zsortafit_npoly8_1689720284_mcmc

# %%
# %run input/param_fit_continuity_12logbins_zsortafit.py --fit_phot 1 --fit_spectra 1 --npoly 8 --outfile output/fit_DF44_aD1_specKCWI_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_aD1_specKCWI_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     stdT_mean: 0
#     fit_spectra: 1
#     fit_phot: 1
#     fit_sigma: False
#     fit_mass: 1
#     wave_range: [0, 10000]
#     max_snr: 1000000
#     npoly: 8
#
#
# ...

# %%
fit_DF44_dexp_phot_specKCWI_zsortafit_npoly8_1649700118_mcmc

# %%
# %run input/param_fit_dexp_zsortafit.py --fit_phot 1 --fit_spectra 1 --npoly 8 --outfile output/fit_DF44_dexo_specKCWI_zsortafit_npoly8 --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_dexo_specKCWI_zsortafit_npoly8
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     fit_spectra: 1
#     fit_phot: 1
#     fit_sigma: False
#     fit_mass: True
#     prior_tau_log: True
#     wave_range: [0, 10000]
#     max_snr: 1000000
# ...

# %% [raw]
# fit_DF44_dexp_utau_phot_1649697872_mcmc

# %%
# %run input/param_fit_dexp.py --fit_phot 1 --fit_spectra 0 --fit_redshift 0 --prior_tau_log 0 --outfile output/fit_DF44_dexo_utau_specKCWI --debug
# Out:
# Run params:
#
#     verbose: 1
#     debug: True
#     outfile: output/fit_DF44_dexo_utau_specKCWI
#     output_pickle: False
#     zcontinuous: 1
#     optimize: False
#     min_method: lm
#     min_opts: {}
#     nmin: 1
#     emcee: False
#     nwalkers: 64
#     niter: 512
#     nburn: [16, 32, 64]
#     interval: 0.2
#     restart_from:
#     initial_disp: 0.1
#     dynesty: False
#     nested_bound: multi
#     nested_sample: slice
#     nested_walks: 48
#     nested_nlive_init: 100
#     nested_nlive_batch: 100
#     nested_dlogz_init: 0.05
#     nested_maxcall: 50000000
#     nested_maxiter: 1000000
#     nested_maxbatch: 10
#     nested_bootstrap: 0
#     nested_target_n_effective: 10000
#     file_data: /Users/kawebb/dragonfly44/Dragonfly44_SFH/data/Dragonfly44/obs_phot_specKCWI_sigma110.h5
#     fit_spectra: 0
#     fit_phot: 1
#     fit_sigma: False
#     fit_mass: True
#     fit_redshift: 0
#     prior_tau_log: 0
#     wave_range: [0, 10000]
#     max_snr: 1000000
# ...

# %%
model
# Out:
# :::::::
# <class 'prospect.models.sedmodel.SpecModel'>
#
# Free Parameters: (name: prior)
# -----------
#   mass: <class 'prospect.models.priors.LogUniform'>(mini=100000000.0,maxi=1000000000000.0)
#   logzsol: <class 'prospect.models.priors.TopHat'>(mini=-2,maxi=0.19)
#   dust2: <class 'prospect.models.priors.TopHat'>(mini=0,maxi=4.0)
#   tage: <class 'prospect.models.priors.TopHat'>(mini=0.001,maxi=13.8)
#   tau: <class 'prospect.models.priors.TopHat'>(mini=0.1,maxi=10)
#   dust_ratio: <class 'prospect.models.priors.ClippedNormal'>(mean=1.0,sigma=0.3,mini=0.0,maxi=2.0)
#   dust_index: <class 'prospect.models.priors.TopHat'>(mini=-2.0,maxi=0.5)
#   duste_umin: <class 'prospect.models.priors.TopHat'>(mini=0.1,maxi=25)
#   duste_qpah: <class 'prospect.models.priors.TopHat'>(mini=0.5,maxi=7.0)
#   duste_gamma: <class 'prospect.models.priors.LogUniform'>(mini=0.001,maxi=0.15)
#
# Fixed Parameters: (name: value [, depends_on])
# -----------
#   zred: [0.02142]
#   sfh: [4]
# ...
